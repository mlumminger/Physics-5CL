# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize

# %%
plt.rcParams["figure.dpi"] = 150
plt.rcParams["text.usetex"] = True
plt.rcParams["font.size"] = 12


# matplotlib.rcParams['mathtext.fontset'] = 'stix'
# matplotlib.rcParams['font.family'] = 'Computer Modern'


plt.rcParams['font.family'] = 'serif' # or 'sans-serif' or 'monospace'
plt.rcParams['font.serif'] = 'cmr10'
plt.rcParams['font.sans-serif'] = 'cmss10'
plt.rcParams['font.monospace'] = 'cmtt10'
plt.rcParams["axes.formatter.use_mathtext"] = True # to fix the minus signs
# %config InlineBackend.figure_format = 'retina'
#plt.rcParams['axes.grid'] = True

# %%
f_A = 18.0
f_A_err = 0.1

f_C = 5.0
F_C_err = 0.1

object_objective_dist = 310.6
object_objective_dist_err = 0.5

object_eyepiece_dist = 423.6
object_eyepiece_dist_err = 0.5

s = object_eyepiece_dist - object_objective_dist - f_A - f_C

near_point = 141.5
near_point_err = 5.4

angular_mag = s*near_point / (f_A * f_C)

angular_mag_err = 0

print(angular_mag)
# Out:
# -141.5
